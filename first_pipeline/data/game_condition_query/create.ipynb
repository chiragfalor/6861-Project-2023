# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = ['Description', 'Ludii code'])

# %%
df.loc[0] = ['In the first turn, player O places their mark on the front slide, 1st row, 3rd column.', 
            '(Add Disc1 to C7)']

# %%
# Out:
# '|    | Description                                                                            | Ludii code        |\n|---:|:---------------------------------------------------------------------------------------|:------------------|\n|  0 | In the first turn, player O places their mark on the front slide, 1st row, 3rd column. | (Add Disc1 to C7) |'

# %%
df = pd.DataFrame(columns = ['task_id', 'language_full', 'language_phrase_1', 'language_phrase_2', 
                            'language_phrase_3', 'language_phrase_4', 'language_phrase_5', 
                            'language_phrase_6', 'language_phrase_7', 'language_phrase_8', 'question_sentence',
                             'code_phrase_1', 'code_phrase_2', 
                            'code_phrase_3', 'code_phrase_4', 'code_phrase_5', 
                            'code_phrase_6', 'code_phrase_7', 'code_phrase_8',
                            'question_code', 'answer'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [task_id, language_full, language_phrase_1, language_phrase_2, language_phrase_3, language_phrase_4, language_phrase_5, language_phrase_6, language_phrase_7, language_phrase_8, question_sentence, code_phrase_1, code_phrase_2, code_phrase_3, code_phrase_4, code_phrase_5, code_phrase_6, code_phrase_7, code_phrase_8, question_code, answer]
# Index: []
#
# [0 rows x 21 columns]

# %%
row_1 = [0, 
         
         "In the first turn, player O places their mark on the front slide, 1st row, 3rd column. In the second turn, player X places their mark on the middle slide, 2nd row, 3rd column. In the third turn, player O places their mark on the back slide, 1st row, 3rd column. In the fourth turn, player X places their mark on the back slide, 2nd row, 2nd column. In the fifth turn, player O places their mark on the middle slide, 1st row, 3rd column.", 
         
         
         
         'In the first turn, player O places their mark on the front slide, 1st row, 3rd column.', 
         
         'In the second turn, player X places their mark on the middle slide, 2nd row, 3rd column.', 
            'In the third turn, player O places their mark on the back slide, 1st row, 3rd column.', 
         'In the fourth turn, player X places their mark on the back slide, 2nd row, 2nd column.', 
         'In the fifth turn, player O places their mark on the middle slide, 1st row, 3rd column.',
                            None, None, None,
         'who wins?',
                            '(Add Disc1 to C7)', '(Add Cross2 to C6)', '(Add Disc1 to C3)', 
                            '(Add Cross2 to B2)', '(Add Disc1 to C11)', None,
                             None, None, None,
                            'player O because three of their marks on the front, middle, and back slide (1st row, 3rd column) form a line.']

# %%
df.loc[0] = row_1

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  In the first turn, player O places their mark ...
#
#                                    language_phrase_1  \
# 0  In the first turn, player O places their mark ...
#
#                                    language_phrase_2  \
# 0  In the second turn, player X places their mark...
#
#                                    language_phrase_3  \
# 0  In the third turn, player O places their mark ...
#
#                                    language_phrase_4  \
# 0  In the fourth turn, player X places their mark...
#
#                                    language_phrase_5 language_phrase_6  \
# 0  In the fifth turn, player O places their mark ...              None
#
#   language_phrase_7 language_phrase_8  ...      code_phrase_1  \
# 0              None              None  ...  (Add Disc1 to C7)
#
#         code_phrase_2      code_phrase_3       code_phrase_4  \
# ...

# %%
row_1 = [1, 
         
         "In the first turn, player O places their mark on the front slide, 1st row, 1st column. In the second turn, player X places their mark on the middle slide, 2nd row, 2nd column. In the third turn, player O places their mark on the middle slide, 1st row, 3rd column. In the fourth turn, player X places their mark on the back slide, 2nd row, 2nd column. In the fifth turn, player O places their mark on the front slide, 2nd row, 2nd column. In the sixth turn, player X places their mark on the middle slide, 1st row, 1st column. In the seventh turn, player O places their mark on the middle slide, 3rd row, 3rd column. In the eighth turn, player X places their mark on the back slide, 1st row, 2nd column.", 
         
         
         
         'In the first turn, player O places their mark on the front slide, 1st row, 1st column.', 
         
         'In the second turn, player X places their mark on the middle slide, 2nd row, 2nd column.', 
            'In the third turn, player O places their mark on the middle slide, 1st row, 3rd column.', 
         'In the fourth turn, player X places their mark on the back slide, 2nd row, 2nd column.', 
         'In the fifth turn, player O places their mark on the front slide, 2nd row, 2nd column.', 
         'In the sixth turn, player X places their mark on the middle slide, 1st row, 1st column.',
         'In the seventh turn, player O places their mark on the middle slide, 3rd row, 3rd column.',
         'In the eighth turn, player X places their mark on the back slide, 1st row, 2nd column.', 'who wins?',
                            '(Add Disc1 to A11)', '(Add Cross2 to B6)', '(Add Disc1 to C7)', 
                            '(Add Cross2 to B2)', '(Add Disc1 to B10)', '(Add Cross2 to A7)',
                             '(Add Disc1 to C5)', '(Add Cross2 to B3)', None,
                            'no one because both players have not formed a line with their marks yet.']

# %%
df.loc[1] = row_1

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  In the first turn, player O places their mark ...
# 1        1  In the first turn, player O places their mark ...
#
#                                    language_phrase_1  \
# 0  In the first turn, player O places their mark ...
# 1  In the first turn, player O places their mark ...
#
#                                    language_phrase_2  \
# 0  In the second turn, player X places their mark...
# 1  In the second turn, player X places their mark...
#
#                                    language_phrase_3  \
# 0  In the third turn, player O places their mark ...
# 1  In the third turn, player O places their mark ...
#
#                                    language_phrase_4  \
# 0  In the fourth turn, player X places their mark...
# 1  In the fourth turn, player X places their mark...
#
#                                    language_phrase_5  \
# 0  In the fifth turn, player O places their mark ...
# ...

# %%
row_1 = [2, 
         
         "In the first turn, player O places their mark on the front slide, 2nd row, 1st column. In the second turn, player X places their mark on the back slide, 1st row, 2nd column. In the third turn, player O places their mark on the middle slide, 2nd row, 2nd column. In the fourth turn, player X places their mark on the middle slide, 1st row, 2nd column. In the fifth turn, player O places their mark on the middle slide, 1st row, 3rd column. In the sixth turn, player X places their mark on the front slide, 1st row, 2nd column.", 
         
         
         
         'In the first turn, player O places their mark on the front slide, 2nd row, 1st column.', 
         
         'In the second turn, player X places their mark on the back slide, 1st row, 2nd column.', 
            'In the third turn, player O places their mark on the middle slide, 2nd row, 2nd column.', 
         'In the fourth turn, player X places their mark on the middle slide, 1st row, 2nd column.', 
         'In the fifth turn, player O places their mark on the middle slide, 1st row, 3rd column.', 
         'In the sixth turn, player X places their mark on the front slide, 1st row, 2nd column.',
         None,
         None, 'who wins?',
                            '(Add Disc1 to A10)', '(Add Cross2 to B3)', '(Add Disc1 to B6)', 
                            '(Add Cross2 to B7)', '(Add Disc1 to C7)', '(Add Cross2 to B11)',
                             None, None, None,
                            'player X because three of their marks on the front, middle, and back slide 1st row, 2nd column form a line']

# %%
df.loc[2] = row_1

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  In the first turn, player O places their mark ...
# 1        1  In the first turn, player O places their mark ...
# 2        2  In the first turn, player O places their mark ...
#
#                                    language_phrase_1  \
# 0  In the first turn, player O places their mark ...
# 1  In the first turn, player O places their mark ...
# 2  In the first turn, player O places their mark ...
#
#                                    language_phrase_2  \
# 0  In the second turn, player X places their mark...
# 1  In the second turn, player X places their mark...
# 2  In the second turn, player X places their mark...
#
#                                    language_phrase_3  \
# 0  In the third turn, player O places their mark ...
# 1  In the third turn, player O places their mark ...
# 2  In the third turn, player O places their mark ...
#
#                                    language_phrase_4  \
# ...

# %%
row_1 = [3, 
         
         "In the first turn, player O places their mark on the back slide, 3rd row, 1st column. In the second turn, player X places their mark on the back slide, 1st row, 1st column. In the third turn, player O places their mark on the middle slide, 1st row, 3rd column. In the fourth turn, player X places their mark on the back slide, 1st row, 2nd column. In the fifth turn, player O places their mark on the middle slide, 2nd row, 2nd column. In the sixth turn, player X places their mark on the back slide, 1st row, 3rd column.", 
         
         
         
         'In the first turn, player O places their mark on the back slide, 3rd row, 1st column.', 
         
         'In the second turn, player X places their mark on the back slide, 1st row, 1st column.', 
            'In the third turn, player O places their mark on the middle slide, 1st row, 3rd column', 
         'In the fourth turn, player X places their mark on the back slide, 1st row, 2nd column.', 
         'In the fifth turn, player O places their mark on the middle slide, 2nd row, 2nd column.', 
         'In the sixth turn, player X places their mark on the back slide, 1st row, 3rd column.',
         None,
         None, 'who wins?',
                            '(Add Disc1 to A1)', '(Add Cross2 to A3)', '(Add Disc1 to C7)', 
                            '(Add Cross2 to B3)', '(Add Disc1 to B6)', '(Add Cross2 to C3)',
                             None, None, None,
                            'Player X because three of their marks on the back slide 1st row form a line.']

# %%
df.loc[3] = row_1

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  In the first turn, player O places their mark ...
# 1        1  In the first turn, player O places their mark ...
# 2        2  In the first turn, player O places their mark ...
# 3        3  In the first turn, player O places their mark ...
#
#                                    language_phrase_1  \
# 0  In the first turn, player O places their mark ...
# 1  In the first turn, player O places their mark ...
# 2  In the first turn, player O places their mark ...
# 3  In the first turn, player O places their mark ...
#
#                                    language_phrase_2  \
# 0  In the second turn, player X places their mark...
# 1  In the second turn, player X places their mark...
# 2  In the second turn, player X places their mark...
# 3  In the second turn, player X places their mark...
#
#                                    language_phrase_3  \
# 0  In the third turn, player O places their mark ...
# ...

# %%
df.to_csv('tictactoe3d.csv')

# %%
df = pd.DataFrame(columns = ['task_id', 'language_full', 'language_phrase_1', 'language_phrase_2', 
                            'language_phrase_3', 'language_phrase_4', 'language_phrase_5', 
                            'language_phrase_6', 'language_phrase_7', 'language_phrase_8', 
                             'language_phrase_9', 'language_phrase_10', 'language_phrase_11',
                             'language_phrase_12', 'language_phrase_13', 'language_phrase_14',
                             
                             'question_sentence',
                             'code_phrase_1', 'code_phrase_2', 
                            'code_phrase_3', 'code_phrase_4', 'code_phrase_5', 
                            'code_phrase_6', 'code_phrase_7', 'code_phrase_8',
                             'code_phrase_9', 'code_phrase_10', 'code_phrase_11',
                             'code_phrase_12', 'code_phrase_13', 'code_phrase_14',
                             
                            'question_code', 'answer'])

# %%
row = [0, 'Player 1 places their piece on the upper right corner of the outer square. Player 2 places their piece on the middle point of the upper side of the inner square.Player 1 places their piece on the middle point of the right side of the outer square.Player 2 places their piece on the middle point of the lower side of the outer square.Player 1 places their piece on the lower right corner of the outer square.',
      'Player 1 places their piece on the upper right corner of the outer square.', 
    'Player 2 places their piece on the middle point of the upper side of the inner square.',
       'Player 1 places their piece on the middle point of the right side of the outer square.', 
       'Player 2 places their piece on the middle point of the lower side of the outer square.', 
       'Player 1 places their piece on the lower right corner of the outer square.', 
       None, None, None,None,None,None,None,None,None,
       "Player 1 want to capture player 2's piece on the middle point of the upper side of the inner square. Is this a valid move?", 
       '(Move Cell 16 - Vertex E5)', 
       '(Move Cell 17 - Vertex C4)', 
       '(Move Cell 16 - Vertex E3)', 
       '(Move Cell 17 - Vertex C1)', 
       '(Move Cell 16 - Vertex E1)', 
       None, None, None,None,None,None,None,None,None,
       '(Remove C4)', 
       'A valid move because player 1 has three of their marks on the right side of the outer square forming a line.'   
      ]

# %%
df.loc[0] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the upper right...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the upper right...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the middle poin...
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the middle poin...
#
#                                    language_phrase_4  \
# 0  Player 2 places their piece on the middle poin...
#
#                                    language_phrase_5 language_phrase_6  \
# 0  Player 1 places their piece on the lower right...              None
#
#   language_phrase_7 language_phrase_8  ... code_phrase_7 code_phrase_8  \
# 0              None              None  ...          None          None
#
#   code_phrase_9 code_phrase_10 code_phrase_11 code_phrase_12 code_phrase_13  \
# ...

# %%
row = [1, 'Player 1 places their piece on the upper left corner of the outer square. Player 2 places their piece on the lower left corner of the outer square. Player 1 places their piece on the middle point of the upper side of the inner square. Player 2 places their piece on the lower right corner of the inner square. Player 1 places their piece on the middle point of the left side of the inner square.',
      'Player 1 places their piece on the upper left corner of the outer square.', 
    'Player 2 places their piece on the lower left corner of the outer square.',
       'Player 1 places their piece on the middle point of the upper side of the inner square.', 
       'Player 2 places their piece on the lower right corner of the inner square.', 
       'Player 1 places their piece on the middle point of the left side of the inner square.', 
       None, None, None,None,None,None,None,None,None,
       "Player 2 wants to place their piece on the upper left corner of the outer square. Is this a valid move?", 
       '(Move Cell 16 - Vertex A5)', 
       '(Move Cell 17 - Vertex A1)', 
       '(Move Cell 16 - Vertex C4)', 
       '(Move Cell 17 - Vertex D2)', 
       '(Move Cell 16 - Vertex B3)', 
       None, None, None,None,None,None,None,None,None,
       '(Move Cell 17 - Vertex A5)', 
       "An invalid move because player 1's piece is on the upper left corner of the outer square."
      ]

# %%
Player 1 places their piece on the upper left corner of the outer square.
Player 2 places their piece on the lower left corner of the outer square.
Player 1 places their piece on the middle point of the upper side of the inner square. 
Player 2 places their piece on the lower right corner of the inner square. 
Player 1 places their piece on the middle point of the left side of the inner square.

Player 2 wants to place their piece on the upper left corner of the outer square. Is this a valid move?

# %%
df.loc[1] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the upper right...
# 1        1  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the upper right...
# 1  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the middle poin...
# 1  Player 2 places their piece on the lower left ...
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the middle poin...
# 1  Player 1 places their piece on the middle poin...
#
#                                    language_phrase_4  \
# 0  Player 2 places their piece on the middle poin...
# 1  Player 2 places their piece on the lower right...
#
#                                    language_phrase_5 language_phrase_6  \
# ...

# %%
row = [2, 'Player 1 places their piece on the upper left corner of the outer square. Player 2 places their piece on the lower left corner of the outer square. Player 1 places their piece on the middle point of the upper side of the inner square. Player 2 places their piece on the lower right corner of the inner square. Player 1 places their piece on the middle point of the left side of the inner square.',
      'Player 1 places their piece on the upper right corner of the outer square.', 
    'Player 2 places their piece on the upper right corner of the inner square.',
       'Player 1 places their piece on the middle point of the right side of the outer square.', 
       'Player 2 places their piece on the middle point of the right side of the inner square.', 
       'Player 1 places their piece on the lower right corner of the outer square.', 
       "Player 1 captures player 2's piece on the middle point of the right side of the inner square.", 
       None, None,None,None,None,None,None,None,
       "Player 2 wants to place their piece on the middle point of the right side of the inner square. Is this a valid move?", 
       '(Move Cell 16 - Vertex E5)', 
       '(Move Cell 17 - Vertex D4)', 
       '(Move Cell 16 - Vertex E3)', 
       '(Move Cell 17 - Vertex D3)', 
       '(Move Cell 16 - Vertex E1)', 
       '(Remove D3)', 
       None, None,None,None,None,None,None,None,
       '(Move Cell 17 - Vertex D3)', 
       'A valid move because currently there is no piece on the middle point of the right side of the inner square.'   
      ]

# %%
Player 1 places their piece on the upper right corner of the outer square.
Player 2 places their piece on the upper right corner of the inner square.
Player 1 places their piece on the middle point of the right side of the outer square. 
Player 2 places their piece on the middle point of the right side of the inner square. 
Player 1 places their piece on the lower right corner of the outer square.
Player 1 captures player 2's piece on the middle point of the right side of the inner square.
Player 2 want to place their piece on the middle point of the right side of the inner square. Is this a valid move?

# %%
df.loc[2] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the upper right...
# 1        1  Player 1 places their piece on the upper left ...
# 2        2  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the upper right...
# 1  Player 1 places their piece on the upper left ...
# 2  Player 1 places their piece on the upper right...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the middle poin...
# 1  Player 2 places their piece on the lower left ...
# 2  Player 2 places their piece on the upper right...
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the middle poin...
# 1  Player 1 places their piece on the middle poin...
# 2  Player 1 places their piece on the middle poin...
#
#                                    language_phrase_4  \
# ...

# %%
row = [3, 'Player 1 places their piece on the upper right corner of the outer square. Player 2 places their piece on the middle point of the right side of the outer square. Player 1 places their piece on the lower right corner of the outer square. Player 2 places their piece on the upper left corner of the outer square. Player 1 places their piece on the middle point of the lower side of the inner square.Player 2 places their piece on the upper right corner of the inner square.Player 1 places their piece on the lower left corner of the outer square.Player 2 places their piece on the middle point of the lower side of the outer square.Player 1 places their piece on the middle point of the upper side of the outer square.Player 2 places their piece on the lower right corner of the inner square.Player 1 places their piece on the upper left corner of the inner square.Player 2 places their piece on the middle point of the left side of the outer square.Player 1 moves their piece from the upper left corner of the inner square to the middle point of the left side of the inner square.',
      'Player 1 places their piece on the upper right corner of the outer square.',
'Player 2 places their piece on the middle point of the right side of the outer square.',
'Player 1 places their piece on the lower right corner of the outer square.',
'Player 2 places their piece on the upper left corner of the outer square.', 
'Player 1 places their piece on the middle point of the lower side of the inner square.',
'Player 2 places their piece on the upper right corner of the inner square.',
'Player 1 places their piece on the lower left corner of the outer square.',
'Player 2 places their piece on the middle point of the lower side of the outer square.',
'Player 1 places their piece on the middle point of the upper side of the outer square.',
'Player 2 places their piece on the lower right corner of the inner square.',
'Player 1 places their piece on the upper left corner of the inner square.',
'Player 2 places their piece on the middle point of the left side of the outer square.',
'Player 1 moves their piece from the upper left corner of the inner square to the middle point of the left side of the inner square.',
None,
'Player 2 want to moves their piece from the middle point of the right side of the outer square to the middle point of the right side of the inner square. Is this a valid move?',
       '(Move Cell 16 - Vertex E5)', 
       '(Move Cell 17 - Vertex E3)', 
       '(Move Cell 16 - Vertex E1)', 
       '(Move Cell 17 - Vertex A5)', 
       '(Move Cell 16 - Vertex C2)', 
       '(Move Cell 17 - Vertex D4)', 
       '(Move Cell 16 - Vertex A1)', 
       '(Move Cell 17 - Vertex C1)', 
       '(Move Cell 16 - Vertex C5)', 
       '(Move Cell 17 - Vertex D2)', 
       '(Move Cell 16 - Vertex B4)', 
       '(Move Cell 17 - Vertex A3)', 
       '(Move B4-B3)', 
         None,
       '(Move E3-D3)', 
       'A valid move because currently there is no piece on the the upper left corner of the outer square, and a piece is allowed to move to an adjacent spot along the line.'   
      ]

# %%
'Player 1 places their piece on the upper right corner of the outer square.',
'Player 2 places their piece on the middle point of the right side of the outer square.',
'Player 1 places their piece on the lower right corner of the outer square.',
'Player 2 places their piece on the upper left corner of the outer square.', 
'Player 1 places their piece on the middle point of the lower side of the inner square.',
'Player 2 places their piece on the upper right corner of the inner square.',
'Player 1 places their piece on the lower left corner of the outer square.',
'Player 2 places their piece on the middle point of the lower side of the outer square.',
'Player 1 places their piece on the middle point of the upper side of the outer square.',
'Player 2 places their piece on the lower right corner of the inner square.',
'Player 1 places their piece on the upper left corner of the inner square.',
'Player 2 places their piece on the middle point of the left side of the outer square.',
'Player 1 moves their piece from the upper left corner of the inner square to the middle point of the left side of the inner square.',
None,
'Player 2 want to moves their piece from the middle point of the right side of the outer square to the middle point of the right side of the inner square. Is this a valid move?',

# %%
'Player 1 places their piece on the upper right corner of the outer square. Player 2 places their piece on the middle point of the right side of the outer square. Player 1 places their piece on the lower right corner of the outer square. Player 2 places their piece on the upper left corner of the outer square. Player 1 places their piece on the middle point of the lower side of the inner square.Player 2 places their piece on the upper right corner of the inner square.Player 1 places their piece on the lower left corner of the outer square.Player 2 places their piece on the middle point of the lower side of the outer square.Player 1 places their piece on the middle point of the upper side of the outer square.Player 2 places their piece on the lower right corner of the inner square.Player 1 places their piece on the upper left corner of the inner square.Player 2 places their piece on the middle point of the left side of the outer square.Player 1 moves their piece from the upper left corner of the inner square to the middle point of the left side of the inner square.'

# %%
df.loc[3] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the upper right...
# 1        1  Player 1 places their piece on the upper left ...
# 2        2  Player 1 places their piece on the upper left ...
# 3        3  Player 1 places their piece on the upper right...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the upper right...
# 1  Player 1 places their piece on the upper left ...
# 2  Player 1 places their piece on the upper right...
# 3  Player 1 places their piece on the upper right...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the middle poin...
# 1  Player 2 places their piece on the lower left ...
# 2  Player 2 places their piece on the upper right...
# 3  Player 2 places their piece on the middle poin...
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the middle poin...
# ...

# %%
df.to_csv('achi.csv')

# %%
#A simple game. 2 is valid, 2 who wins
df = pd.DataFrame(columns = ['task_id', 'language_full', 'language_phrase_1', 'language_phrase_2', 
                            'language_phrase_3', 'language_phrase_4', 'language_phrase_5', 
                            'language_phrase_6', 'language_phrase_7', 'language_phrase_8', 'question_sentence',
                             'code_phrase_1', 'code_phrase_2', 
                            'code_phrase_3', 'code_phrase_4', 'code_phrase_5', 
                            'code_phrase_6', 'code_phrase_7', 'code_phrase_8',
                            'question_code', 'answer'])

# %%
row = [0, 'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column. Player 2 moves their piece from 1st row, 3rd column to 1st row, 4th column. Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column. Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column. Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column. Player 1 moves their piece from 3rd row, 3rd column to 2nd row, 3rd column.', 
      'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.', 
      'Player 2 moves their piece from 1st row, 3rd column to 1st row, 4th column.', 
      'Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column.', 
      'Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 3rd row, 3rd column to 2nd row, 3rd column.', 
      None, 
      'who wins?', 
      '(Move D4-D3)', 
      '(Move C4-D4)', 
      '(Move B4-B3)', 
      '(Move B1-B2)', 
      '(Move C1-C2)', 
      '(Move D1-D2)', 
      '(Move C2-C3)', 
      None, 
      None, 
      'Player 1 wins because three of their pieces form a line on the 2nd row.']

# %%
df.loc[0] = row

# %%
Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.
Player 2 moves their piece from 1st row, 3rd column to 1st row, 4th column.
Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column.
Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.
Player 1 moves their piece from 3rd row, 3rd column to 2nd row, 3rd column.

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_2  \
# 0  Player 2 moves their piece from 1st row, 3rd c...
#
#                                    language_phrase_3  \
# 0  Player 1 moves their piece from 1st row, 2nd c...
#
#                                    language_phrase_4  \
# 0  Player 2 moves their piece from 4th row, 2nd c...
#
#                                    language_phrase_5  \
# 0  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_6  \
# 0  Player 2 moves their piece from 4th row, 4th c...
#
#                                    language_phrase_7 language_phrase_8  ...  \
# 0  Player 1 moves their piece from 3rd row, 3rd c...              None  ...
#
# ...

# %%
row = [1, 'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.Player 1 moves their piece from 1st row, 2nd column to 1st row, 3rd column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.', 
      'Player 1 moves their piece from 1st row, 2nd column to 1st row, 3rd column.', 
      None, 
      None, 
      None, 
      None, 
      None, 
      'Player 2 want to move their piece from 2nd row, 3rd column to 3rd row, 3rd column. Is this a valid move?', 
      '(Move C1-C2)', 
      '(Move C4-C3)', 
      '(Move B4-C4)', 
      None, 
      None, 
      None, 
      None, 
      None, 
      '(Move C3-C2)', 
      "An invalid move because player 1's piece is currently on the 3rd row, 3rd column."]

# %%
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.
Player 1 moves their piece from 1st row, 2nd column to 1st row, 3rd column.

Player 2 want to move their piece from 2nd row, 3rd column to 3rd row, 3rd column. Is this a valid move?

# %%
df.loc[1] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_2  \
# 0  Player 2 moves their piece from 1st row, 3rd c...
# 1  Player 2 moves their piece from 1st row, 3rd c...
#
#                                    language_phrase_3  \
# 0  Player 1 moves their piece from 1st row, 2nd c...
# 1  Player 1 moves their piece from 1st row, 2nd c...
#
#                                    language_phrase_4  \
# 0  Player 2 moves their piece from 4th row, 2nd c...
# 1                                               None
#
#                                    language_phrase_5  \
# 0  Player 1 moves their piece from 4th row, 3rd c...
# ...

# %%
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.
Player 1 moves their piece from 4th row, 1st column to 4th row, 2nd column.

Player 2 want to move their piece from 1st row, 3rd column to 2nd row, 3rd column. Is this a valid move?

# %%
row = [2, 'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column. Player 1 moves their piece from 4th row, 1st column to 4th row, 2nd column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.', 
      'Player 1 moves their piece from 4th row, 1st column to 4th row, 2nd column.', 
      None, 
      None, 
      None, 
      None, 
      None, 
      'Player 2 want to move their piece from 1st row, 3rd column to 2nd row, 3rd column. Is this a valid move?', 
      '(Move C1-C2)', 
      '(Move B1-B2)', 
      '(Move A1-B1)', 
      None, 
      None, 
      None, 
      None, 
      None, 
      '(Move C4-C3)', 
      'A valid move because currently there is no piece on the 2nd row, 3rd column, and a piece is allowed to move into an adjacent orthogonal empty cell']

# %%
df.loc[2] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_2  \
# 0  Player 2 moves their piece from 1st row, 3rd c...
# 1  Player 2 moves their piece from 1st row, 3rd c...
# 2  Player 2 moves their piece from 4th row, 2nd c...
#
#                                    language_phrase_3  \
# 0  Player 1 moves their piece from 1st row, 2nd c...
# 1  Player 1 moves their piece from 1st row, 2nd c...
# 2  Player 1 moves their piece from 4th row, 1st c...
#
#                                    language_phrase_4  \
# ...

# %%
row = [3, 'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column. Player 1 moves their piece from 1st row, 4th column to 1st row, 3rd column. Player 2 moves their piece from 2nd row, 3rd column to 2nd row, 2nd column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.', 
      'Player 1 moves their piece from 1st row, 4th column to 1st row, 3rd column.', 
      'Player 2 moves their piece from 2nd row, 3rd column to 2nd row, 2nd column.', 
      None, 
      None, 
      None, 
      None, 
      'who wins?', 
      '(Move C1-C2)', 
      '(Move C4-C3)', 
      '(Move D4-C4)', 
      '(Move C3-B3)', 
      None, 
      None, 
      None, 
      None, 
      None, 
      'No one because no one has formed a line with 3 of their pieces yet.']

# %%
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.
Player 1 moves their piece from 1st row, 4th column to 1st row, 3rd column.
Player 2 moves their piece from 2nd row, 3rd column to 2nd row, 2nd column.

# %%
df.loc[3] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_2  \
# 0  Player 2 moves their piece from 1st row, 3rd c...
# 1  Player 2 moves their piece from 1st row, 3rd c...
# 2  Player 2 moves their piece from 4th row, 2nd c...
# 3  Player 2 moves their piece from 1st row, 3rd c...
#
#                                    language_phrase_3  \
# 0  Player 1 moves their piece from 1st row, 2nd c...
# ...

# %%
row = [4, 'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column. Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column. Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 2nd row, 1st column to 2nd row, 2nd column. Player 1 moves their piece from 3rd row, 3rd column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.', 
      'Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 2nd row, 1st column to 2nd row, 2nd column.', 
      'Player 1 moves their piece from 3rd row, 3rd column to 3rd row, 4th column.', 
      None, 
      None, 
      None, 
      'Player 2 want to move their piece from 4th row, 4th column to 3rd row, 3rd column. Is this a valid move?', 
      '(Move D4-D3)', 
      '(Move A4-A3)', 
      '(Move C1-C2)', 
      '(Move A3-B3)', 
      '(Move C2-D2)', 
      None, 
      None, 
      None, 
      '(Move D1-C2)', 
      'No since the piece are not allowed to move diagonally.']

# %%
Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.
Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column.
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 2nd row, 1st column to 2nd row, 2nd column.
Player 1 moves their piece from 3rd row, 3rd column to 3rd row, 4th column.

Player 2 want to move their piece from 4th row, 4th column to 3rd row, 3rd column. Is this a valid move?

# %%
df.loc[4] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
# 4        4  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
# 4  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_2  \
# 0  Player 2 moves their piece from 1st row, 3rd c...
# 1  Player 2 moves their piece from 1st row, 3rd c...
# 2  Player 2 moves their piece from 4th row, 2nd c...
# ...

# %%
row = [5, 'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column. Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column. Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 2nd row, 1st column to 2nd row, 2nd column. Player 1 moves their piece from 3rd row, 3rd column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.', 
      'Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.', 
      'Player 1 moves their piece from 2nd row, 4th column to 3rd row, 4th column.', 
      'Player 2 moves their piece from 3rd row, 2nd column to 3rd row, 3rd column.', 
      None, 
      None, 
      None, 
      None, 
      'Who wins?', 
      '(Move D4-D3)', 
      '(Move B1-B2)', 
      '(Move D3-D2)', 
      '(Move B2-C2)', 
      None, 
      None, 
      None, 
      None, 
      None, 
      'No one because no one has formed a line with 3 of their pieces yet.']

# %%
Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.
Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.
Player 1 moves their piece from 2nd row, 4th column to 3rd row, 4th column.
Player 2 moves their piece from 3rd row, 2nd column to 3rd row, 3rd column.

# %%
df.loc[5] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
# 4        4  Player 1 moves their piece from 1st row, 4th c...
# 5        5  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
# 4  Player 1 moves their piece from 1st row, 4th c...
# 5  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_2  \
# 0  Player 2 moves their piece from 1st row, 3rd c...
# ...

# %%
row = [6, 'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column. Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column. Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column. Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column. Player 1 moves their piece from 2nd row, 2nd column to 1st row, 2nd column.', 
      'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.', 
      'Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.', 
      'Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column.', 
      'Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 2nd row, 2nd column to 1st row, 2nd column.', 
      None, 
      None, 
      None, 
      'Player 2 want to move their piece from 2nd row, 3rd column to 2nd row, 2nd column. Is this a valid move?', 
      '(Move D4-D3)', 
      '(Move C4-C3)', 
      '(Move B4-B3)', 
      '(Move D1-D2)', 
      '(Move B3-B4)', 
      None, 
      None, 
      None, 
      '(Move C3-B3)', 
      'A valid move because currently there is no piece on the 2nd row, 2nd column, and a piece is allowed to move into an adjacent orthogonal empty cell']

# %%
Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.
Player 2 moves their piece from 1st row, 3rd column to 2nd row, 3rd column.
Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column.
Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.
Player 1 moves their piece from 2nd row, 2nd column to 1st row, 2nd column.

Player 2 want to move their piece from 2nd row, 3rd column to 2nd row, 2nd column. Is this a valid move?

# %%
df.loc[6] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
# 4        4  Player 1 moves their piece from 1st row, 4th c...
# 5        5  Player 1 moves their piece from 1st row, 4th c...
# 6        6  Player 1 moves their piece from 1st row, 4th c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
# 4  Player 1 moves their piece from 1st row, 4th c...
# 5  Player 1 moves their piece from 1st row, 4th c...
# 6  Player 1 moves their piece from 1st row, 4th c...
#
# ...

# %%
row = [7, 'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column. Player 1 moves their piece from 4th row, 1st column to 3rd row, 1st column. Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column. Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column. Player 2 moves their piece from 1st row, 3rd column to 1st row, 4th column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 4th row, 1st column to 3rd row, 1st column.', 
      'Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column.', 
      'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.', 
      'Player 2 moves their piece from 1st row, 3rd column to 1st row, 4th column.', 
      None, 
      None, 
      'Who wins?', 
      '(Move C1-C2)', 
      '(Move D1-D2)', 
      '(Move A1-A2)', 
      '(Move A4-A3)', 
      '(Move D4-D3)', 
      '(Move C4-D4)', 
      None, 
      None, 
      None, 
      'No one because no one has formed a line with 3 of their pieces yet.']

# %%
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.
Player 1 moves their piece from 4th row, 1st column to 3rd row, 1st column.
Player 2 moves their piece from 1st row, 1st column to 2nd row, 1st column.
Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.
Player 2 moves their piece from 1st row, 3rd column to 1st row, 4th column.

# %%
df.loc[7] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
# 4        4  Player 1 moves their piece from 1st row, 4th c...
# 5        5  Player 1 moves their piece from 1st row, 4th c...
# 6        6  Player 1 moves their piece from 1st row, 4th c...
# 7        7  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
# 4  Player 1 moves their piece from 1st row, 4th c...
# 5  Player 1 moves their piece from 1st row, 4th c...
# ...

# %%
row = [8, 'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column. Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column. Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column. Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.', 
      'Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.', 
      'Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.', 
      'Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      None, 
      None, 
      None, 
      None, 
      'Player 1 want to move their piece from 2nd row, 4th column to 3rd row, 4th column. Is this a valid move?', 
      '(Move C1-C2)', 
      '(Move B1-B2)', 
      '(Move D4-D3)', 
      '(Move D1-D2)', 
      None, 
      None, 
      None, 
      None, 
      '(Move D3-D2)', 
      "An invalid move because player 2's piece is currently on the 3rd row, 4th column."]

# %%
Player 1 moves their piece from 4th row, 3rd column to 3rd row, 3rd column.
Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.
Player 1 moves their piece from 1st row, 4th column to 2nd row, 4th column.
Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.

Player 1 want to move their piece from 2nd row, 4th column to 3rd row, 4th column. Is this a valid move?

# %%
df.loc[8] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
# 4        4  Player 1 moves their piece from 1st row, 4th c...
# 5        5  Player 1 moves their piece from 1st row, 4th c...
# 6        6  Player 1 moves their piece from 1st row, 4th c...
# 7        7  Player 1 moves their piece from 4th row, 3rd c...
# 8        8  Player 1 moves their piece from 4th row, 3rd c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
# 4  Player 1 moves their piece from 1st row, 4th c...
# ...

# %%
row = [9, 'Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column. Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column. Player 1 moves their piece from 2nd row, 2nd column to 2nd row, 1st column. Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      'Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column.', 
      'Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.', 
      'Player 1 moves their piece from 2nd row, 2nd column to 2nd row, 1st column.', 
      'Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.', 
      None, 
      None, 
      None, 
      None, 
      'Player 1 want to move their piece from 4th row, 3rd column to 3rd row, 3rd column. Is this a valid move?', 
      '(Move B4-B3)', 
      '(Move B1-B2)', 
      '(Move B3-A3)', 
      '(Move D1-D2)', 
      None, 
      None, 
      None, 
      None, 
      '(Move C1-C2)', 
      "A valid move because currently there is no piece on the 3rd row, 3rd column, and a piece is allowed to move into an adjacent orthogonal empty cell"]

# %%
Player 1 moves their piece from 1st row, 2nd column to 2nd row, 2nd column.
Player 2 moves their piece from 4th row, 2nd column to 3rd row, 2nd column.
Player 1 moves their piece from 2nd row, 2nd column to 2nd row, 1st column.
Player 2 moves their piece from 4th row, 4th column to 3rd row, 4th column.

Player 1 want to move their piece from 4th row, 3rd column to 3rd row, 3rd column. Is this a valid move?

# %%
df.loc[9] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 moves their piece from 1st row, 4th c...
# 1        1  Player 1 moves their piece from 4th row, 3rd c...
# 2        2  Player 1 moves their piece from 4th row, 3rd c...
# 3        3  Player 1 moves their piece from 4th row, 3rd c...
# 4        4  Player 1 moves their piece from 1st row, 4th c...
# 5        5  Player 1 moves their piece from 1st row, 4th c...
# 6        6  Player 1 moves their piece from 1st row, 4th c...
# 7        7  Player 1 moves their piece from 4th row, 3rd c...
# 8        8  Player 1 moves their piece from 4th row, 3rd c...
# 9        9  Player 1 moves their piece from 1st row, 2nd c...
#
#                                    language_phrase_1  \
# 0  Player 1 moves their piece from 1st row, 4th c...
# 1  Player 1 moves their piece from 4th row, 3rd c...
# 2  Player 1 moves their piece from 4th row, 3rd c...
# 3  Player 1 moves their piece from 4th row, 3rd c...
# ...

# %%
df.to_csv('asimplegame.csv')

# %%
df = pd.DataFrame(columns = ['task_id', 'language_full', 'language_phrase_1', 'language_phrase_2', 
                            'language_phrase_3', 'language_phrase_4', 'language_phrase_5', 
                            'language_phrase_6', 'language_phrase_7', 'language_phrase_8', 'question_sentence',
                             'code_phrase_1', 'code_phrase_2', 
                            'code_phrase_3', 'code_phrase_4', 'code_phrase_5', 
                            'code_phrase_6', 'code_phrase_7', 'code_phrase_8',
                            'question_code', 'answer'])

# %%
#do guti
# 2 winning, 2 valid moves
row = [0, 'Player 1 places their piece on the lower right corner. Player 2 places their piece on the upper right corner. Player 1 places their piece on the lower left corner. Player 2 places their piece on the upper left corner. Player 1 moves their piece from the lower right corner to the center. Player 2 moves their piece from the upper right corner to the lower right corner. Player 1 moves their piece from the center to the upper right corner.', 
      'Player 1 places their piece on the lower right corner.', 
      'Player 2 places their piece on the upper right corner.', 
      'Player 1 places their piece on the lower left corner.', 
      'Player 2 places their piece on the upper left corner.', 
      'Player 1 moves their piece from the lower right corner to the center.', 
      'Player 2 moves their piece from the upper right corner to the lower right corner.', 
      'Player 1 moves their piece from the center to the upper right corner.', 
      None, 
      'Player 2 want to move their piece from the upper left corner to the center. Is this a valid move?', 
      '(Move Cell 5 - Vertex C1)', 
      '(Move Cell 6 - Vertex C3)', 
      '(Move Cell 5 - Vertex A1)', 
      '(Move Cell 6 - Vertex A3)', 
      '(Move C1-B2)', 
      '(Move C3-C1)', 
      '(Move B2-C3)', 
      None, 
      '(Move A3-B2)', 
      'A valid move']

# %%
Player 1 places their piece on the lower right corner.
Player 2 places their piece on the upper right corner. 
Player 1 places their piece on the lower left corner.
Player 2 places their piece on the upper left corner.
Player 1 moves their piece from the lower right corner to the center.
Player 2 moves their piece from the upper right corner to the lower right corner.
Player 1 moves their piece from the center to the upper right corner.
Player 2 want to move their piece from the upper left corner to the center. Is this a valid move?

# %%
df.loc[0] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the lower right...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the lower right...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the upper right...
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the lower left ...
#
#                                    language_phrase_4  \
# 0  Player 2 places their piece on the upper left ...
#
#                                    language_phrase_5  \
# 0  Player 1 moves their piece from the lower righ...
#
#                                    language_phrase_6  \
# 0  Player 2 moves their piece from the upper righ...
#
#                                    language_phrase_7 language_phrase_8  ...  \
# 0  Player 1 moves their piece from the center to ...              None  ...
#
# ...

# %%
row = [1, 'Player 1 places their piece on the lower right corner. Player 2 places their piece on the upper left corner. Player 1 places their piece on the upper right corner. Player 2 places their piece on the center. Player 1 moves their piece from the lower right corner to the lower left corner. Player 2 moves their piece from the center to the lower right corner. Player 1 moves their piece from the lower left corner to the center.', 
      'Player 1 places their piece on the lower right corner.', 
      'Player 2 places their piece on the upper left corner.', 
      'Player 1 places their piece on the upper right corner.', 
      'Player 2 places their piece on the center.', 
      'Player 1 moves their piece from the lower right corner to the lower left corner.', 
      'Player 2 moves their piece from the center to the lower right corner.', 
      'Player 1 moves their piece from the lower left corner to the center.', 
      None, 
      'Player 2 want to move their piece from the lower right corner to the center. Is this a valid move?', 
      '(Move Cell 5 - Vertex C1)', 
      '(Move Cell 6 - Vertex A3)', 
      '(Move Cell 5 - Vertex C3)', 
      '(Move Cell 6 - Vertex B2)', 
      '(Move C1-A1)', 
      '(Move B2-C1)', 
      '(Move A1-B2)', 
      None, 
      '(Move C1-B2)', 
      'An invalid move']

# %%
Player 1 places their piece on the lower right corner.
Player 2 places their piece on the upper left corner. 
Player 1 places their piece on the upper right corner.
Player 2 places their piece on the center.
Player 1 moves their piece from the lower right corner to the lower left corner.
Player 2 moves their piece from the center to the lower right corner.
Player 1 moves their piece from the lower left corner to the center.
Player 2 want to move their piece from the lower right corner to the center. Is this a valid move?

# %%
df.loc[1] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the lower right...
# 1        1  Player 1 places their piece on the lower right...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the lower right...
# 1  Player 1 places their piece on the lower right...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the upper right...
# 1  Player 2 places their piece on the upper left ...
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the lower left ...
# 1  Player 1 places their piece on the upper right...
#
#                                    language_phrase_4  \
# 0  Player 2 places their piece on the upper left ...
# 1         Player 2 places their piece on the center.
#
#                                    language_phrase_5  \
# 0  Player 1 moves their piece from the lower righ...
# ...

# %%
row = [2, 'Player 1 places their piece on the upper left corner. Player 2 places their piece on the center. Player 1 places their piece on the lower left corner. Player 2 places their piece on the lower right corner.', 
      'Player 1 places their piece on the upper left corner.', 
      'Player 2 places their piece on the center.', 
      'Player 1 places their piece on the lower left corner.', 
      'Player 2 places their piece on the lower right corner.', 
      None, 
      None, 
      None, 
      None, 
      'who wins?', 
      '(Move Cell 5 - Vertex A3)', 
      '(Move Cell 6 - Vertex B2)', 
      '(Move Cell 5 - Vertex A1)', 
      '(Move Cell 6 - Vertex C1)', 
      None, 
      None, 
      None, 
      None, 
      None, 
      'Player 2']

# %%
Player 1 places their piece on the upper left corner.
Player 2 places their piece on the center. 
Player 1 places their piece on the lower left corner.
Player 2 places their piece on the lower right corner.

# %%
df.loc[2] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the lower right...
# 1        1  Player 1 places their piece on the lower right...
# 2        2  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the lower right...
# 1  Player 1 places their piece on the lower right...
# 2  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the upper right...
# 1  Player 2 places their piece on the upper left ...
# 2         Player 2 places their piece on the center.
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the lower left ...
# 1  Player 1 places their piece on the upper right...
# 2  Player 1 places their piece on the lower left ...
#
#                                    language_phrase_4  \
# ...

# %%
row = [3, 'Player 1 places their piece on the upper left corner. Player 2 places their piece on the center. Player 1 places their piece on the upper right corner. Player 2 places their piece on the lower right corner. Player 1 moves their piece from the upper left corner to the lower left corner. Player 2 moves their piece from the center to the upper left corner. Player 1 moves their piece from the upper left right to the center. Player 2 moves their piece from the lower right corner to the upper right corner.', 
      'Player 1 places their piece on the upper left corner.', 
      'Player 2 places their piece on the center.', 
      'Player 1 places their piece on the upper right corner.', 
      'Player 2 places their piece on the lower right corner.', 
      'Player 1 moves their piece from the upper left corner to the lower left corner.', 
      'Player 2 moves their piece from the center to the upper left corner.', 
      'Player 1 moves their piece from the upper left right to the center.', 
      'Player 2 moves their piece from the lower right corner to the upper right corner.', 
      'who wins?', 
      '(Move Cell 5 - Vertex A3)', 
      '(Move Cell 6 - Vertex B2)', 
      '(Move Cell 5 - Vertex C3)', 
      '(Move Cell 6 - Vertex C1)', 
      '(Move A3-A1)', 
      '(Move B2-A3)', 
      '(Move C3-B2)', 
      '(Move C1-C3)', 
      None, 
      'No one']

# %%
Player 1 places their piece on the upper left corner.
Player 2 places their piece on the center. 
Player 1 places their piece on the upper right corner.
Player 2 places their piece on the lower right corner.
Player 1 moves their piece from the upper left corner to the lower left corner.
Player 2 moves their piece from the center to the upper left corner.
Player 1 moves their piece from the upper left right to the center.
Player 2 moves their piece from the lower right corner to the upper right corner.

# %%
df.loc[3] = row

# %%
df
# Out:
#    task_id                                      language_full  \
# 0        0  Player 1 places their piece on the lower right...
# 1        1  Player 1 places their piece on the lower right...
# 2        2  Player 1 places their piece on the upper left ...
# 3        3  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_1  \
# 0  Player 1 places their piece on the lower right...
# 1  Player 1 places their piece on the lower right...
# 2  Player 1 places their piece on the upper left ...
# 3  Player 1 places their piece on the upper left ...
#
#                                    language_phrase_2  \
# 0  Player 2 places their piece on the upper right...
# 1  Player 2 places their piece on the upper left ...
# 2         Player 2 places their piece on the center.
# 3         Player 2 places their piece on the center.
#
#                                    language_phrase_3  \
# 0  Player 1 places their piece on the lower left ...
# ...

# %%
df.to_csv('doguti.csv')

# %%
#dorvoncag
df = pd.DataFrame(columns = ['task_id', 'language_full', 'language_phrase_1', 'language_phrase_2', 
                            'language_phrase_3', 'language_phrase_4', 'language_phrase_5', 
                            'language_phrase_6', 'language_phrase_7', 'language_phrase_8', 'question_sentence',
                             'code_phrase_1', 'code_phrase_2', 
                            'code_phrase_3', 'code_phrase_4', 'code_phrase_5', 
                            'code_phrase_6', 'code_phrase_7', 'code_phrase_8',
                            'question_code', 'answer'])
